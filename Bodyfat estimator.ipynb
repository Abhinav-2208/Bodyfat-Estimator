# %% [markdown]
# # Imporrting libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # importing the dataset

# %%
df=pd.read_csv("bodyfat.csv")

# %%
df.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  252 non-null    float64
#  1   BodyFat  252 non-null    float64
#  2   Age      252 non-null    int64
#  3   Weight   252 non-null    float64
#  4   Height   252 non-null    float64
#  5   Neck     252 non-null    float64
#  6   Chest    252 non-null    float64
#  7   Abdomen  252 non-null    float64
#  8   Hip      252 non-null    float64
#  9   Thigh    252 non-null    float64
#  10  Knee     252 non-null    float64
#  11  Ankle    252 non-null    float64
#  12  Biceps   252 non-null    float64
#  13  Forearm  252 non-null    float64
#  14  Wrist    252 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 29.7 KB

# %%
def plotdistplots(col):
    plt.figure(figsize=(12,5))
    sn.distplot(df['BodyFat'],color='magenta', hist=False,label='bodyfat')
    sn.distplot(df[col],color='red',hist=False, label=col)
    plt.legend()
    plt.show()

cols=list(df.columns)
for i in cols:
    print(f'Distribution plots for {i} feature is shown below')
    plotdistplots(i)
    print("-"*100)
# Out:
# Distribution plots for Density feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for BodyFat feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Age feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Weight feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Height feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Neck feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Chest feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Abdomen feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Hip feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Thigh feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Knee feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Ankle feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Biceps feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Forearm feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Wrist feature is shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ----------------------------------------------------------------------------------------------------

# %%
import scipy.stats as stats

# %%
def drawplots(df,col):
    plt.figure(figsize=(15,7))
    plt.subplot(1,3,1)
    plt.hist(df[col],color='magenta')
    
    plt.subplot(1,3,2)
    stats.probplot(df[col],dist='norm',plot=plt)
    
    plt.subplot(1,3,3)
    sn.boxplot(df[col],color='magenta')
    
    plt.show()

cols=list(df.columns)
for i in range(len(cols)):
    print(f'Distribution plots for the feature {cols[i]} are shown below')
    drawplots(df,cols[i])
    print("="*100)
# Out:
# Distribution plots for the feature Density are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================
# Distribution plots for the feature BodyFat are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================
# Distribution plots for the feature Age are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================
# Distribution plots for the feature Weight are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================
# Distribution plots for the feature Height are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================
# Distribution plots for the feature Neck are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================
# Distribution plots for the feature Chest are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================
# Distribution plots for the feature Abdomen are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================
# Distribution plots for the feature Hip are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================
# Distribution plots for the feature Thigh are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================
# Distribution plots for the feature Knee are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================
# Distribution plots for the feature Ankle are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================
# Distribution plots for the feature Biceps are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================
# Distribution plots for the feature Forearm are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================
# Distribution plots for the feature Wrist are shown below
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ====================================================================================================

# %% [markdown]
# # Checking for outliers

# %%
upperlimit=[]
lowerlimit=[]
for i in df.columns:
    upperlimit.append(df[i].mean()+(df[i].std())*4)
    lowerlimit.append(df[i].mean()-(df[i].std())*4)

# %%
cols=list(df.columns)
j=0
for i in range(len(cols)):
    temp=df.loc[(df[cols[i]]>upperlimit[j])&(df[cols[i]]<lowerlimit[j])]
    j+=1

# %%
temp
# Out:
# Empty DataFrame
# Columns: [Density, BodyFat, Age, Weight, Height, Neck, Chest, Abdomen, Hip, Thigh, Knee, Ankle, Biceps, Forearm, Wrist]
# Index: []

# %% [markdown]
# # Using ExtraTrees Regressor for feature Selection

# %%
data=df.copy()
test=data['BodyFat']
train=data.drop(['BodyFat'],axis=1)

# %%
from sklearn.ensemble import ExtraTreesRegressor
er=ExtraTreesRegressor()
er.fit(train,test)
# Out:
# ExtraTreesRegressor()

# %%
series=pd.Series(er.feature_importances_,index=train.columns)
series.nlargest(5).plot(kind='barh',color='green')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Using Mutual Information Gain for Feature Selection

# %%
from sklearn.feature_selection import mutual_info_regression
mr=mutual_info_regression(train,test)

# %%
plotdata=pd.Series(mr,index=train.columns)
plotdata.nlargest(5).plot(kind='barh',color='green')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Removing Correlation

# %%
data
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %%
plt.figure(figsize=(15,7))
sn.heatmap(df.corr(),annot=True,cmap='plasma')
# Out:
# <AxesSubplot:>

# %%
def correlation(df,threshold):
    
    colcor=set()
    
    cormat=df.corr()
    for i in range(len(cormat)):
        
        for j in range(i):
            
            if abs(cormat.iloc[i][j])>threshold:
                
                colname=cormat.columns[i]
                colcor.add(colname)
                
    return colcor

ans=correlation(train,threshold=0.85)

ans
# Out:
# {'Abdomen', 'Chest', 'Hip', 'Knee', 'Thigh'}

# %% [markdown]
# ## From the above features selection techniques we can say that the features are recommended by the Extra tree regressor

# %% [markdown]
# Mutual_information_gain are correct and from the correlation map we get to observe the similar pattern we noticed
# that abdomen and hip are having similar features. They are having collinearity, same goes with knee and thigh, we can
# keep any one of them and we noticed that feature abdomen gave more feature importance score in comparision to Hip, so i will be selecting that..

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\abhin\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\abhin\anaconda3\lib\site-packages (from statsmodels) (1.21.5)
# Requirement already satisfied: scipy>=1.3 in c:\users\abhin\anaconda3\lib\site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\abhin\anaconda3\lib\site-packages (from statsmodels) (1.4.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\abhin\anaconda3\lib\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\abhin\anaconda3\lib\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\abhin\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abhin\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\abhin\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in c:\users\abhin\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
temp=data[list(data.columns)]
info=pd.DataFrame()
info['VIF']=[variance_inflation_factor(temp.values,i) for i in range(temp.shape[1])]
info['column']=temp.columns
info
# Out:
#             VIF   column
# 0   3695.622377  Density
# 1     33.845429  BodyFat
# 2     31.376101      Age
# 3   1238.097164   Weight
# 4    613.410514   Height
# 5   1081.965633     Neck
# 6   1374.457425    Chest
# 7   1332.624257  Abdomen
# 8   2933.636131      Hip
# 9   1017.257501    Thigh
# 10  1187.890413     Knee
# 11   356.293529    Ankle
# 12   419.391664   Biceps
# 13   454.571766  Forearm
# 14  1349.973920    Wrist

# %%
cols1=list(series.nlargest(5).index)
cols2=list(plotdata.nlargest(5).index)
cols1,cols2
# Out:
# (['Density', 'Abdomen', 'Chest', 'Hip', 'Weight'],
#  ['Density', 'Abdomen', 'Chest', 'Hip', 'Weight'])

# %% [markdown]
# ###  We will go with the weight and Hip as Hip and Thigh are very much related,so we will select the cols1 feature and drop every
# other feature,if that doesn't produce any further importance we will try with some other feature.

# %%
totrain=train[cols1]
totrain.head()
# Out:
#    Density  Abdomen  Chest    Hip  Weight
# 0   1.0708     85.2   93.1   94.5  154.25
# 1   1.0853     83.0   93.6   98.7  173.25
# 2   1.0414     87.9   95.8   99.2  154.00
# 3   1.0751     86.4  101.8  101.2  184.75
# 4   1.0340    100.0   97.3  101.9  184.25

# %%
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn import metrics
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression,Lasso,Ridge

# %%
x_train,x_test,y_train,y_test=train_test_split(totrain,test,test_size=0.2)
x_train.shape,x_test.shape
# Out:
# ((201, 5), (51, 5))

# %%
reg=DecisionTreeRegressor()
reg.fit(x_train,y_train)
plt.figure(figsize=(15,7))
tree.plot_tree(reg,filled=True)
# Out:
# [Text(0.4988082627118644, 0.9545454545454546, 'X[0] <= 1.056\nsquared_error = 74.598\nsamples = 201\nvalue = 19.043'),
#  Text(0.2174258474576271, 0.8636363636363636, 'X[0] <= 1.036\nsquared_error = 25.98\nsamples = 103\nvalue = 26.017'),
#  Text(0.05826271186440678, 0.7727272727272727, 'X[0] <= 1.016\nsquared_error = 15.236\nsamples = 34\nvalue = 31.853'),
#  Text(0.01694915254237288, 0.6818181818181818, 'X[0] <= 1.003\nsquared_error = 16.347\nsamples = 3\nvalue = 41.9'),
#  Text(0.012711864406779662, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 47.5'),
#  Text(0.0211864406779661, 0.5909090909090909, 'X[0] <= 1.012\nsquared_error = 1.0\nsamples = 2\nvalue = 39.1'),
#  Text(0.01694915254237288, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 40.1'),
#  Text(0.025423728813559324, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 38.1'),
#  Text(0.09957627118644068, 0.6818181818181818, 'X[0] <= 1.029\nsquared_error = 4.414\nsamples = 31\nvalue = 30.881'),
#  Text(0.057203389830508475, 0.5909090909090909, 'X[1] <= 113.65\nsquared_error = 1.506\nsamples = 14\nvalue = 32.9'),
#  Text(0.03389830508474576, 0.5, 'X[0] <= 1.026\nsquared_error = 0.364\nsamples = 10\nvalue = 32.2'),
#  Text(0.01694915254237288, 0.4090909090909091, 'X[1] <= 106.2\nsquared_error = 0.018\nsamples = 5\nvalue = 32.76'),
#  Text(0.00847457627118644, 0.3181818181818182, 'X[0] <= 1.025\nsquared_error = 0.002\nsamples = 3\nvalue = 32.867'),
#  Text(0.00423728813559322, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 32.9'),
#  Text(0.012711864406779662, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 32.8'),
#  Text(0.025423728813559324, 0.3181818181818182, 'X[4] <= 215.375\nsquared_error = 0.0\nsamples = 2\nvalue = 32.6'),
#  Text(0.0211864406779661, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 32.6'),
#  Text(0.029661016949152543, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 32.6'),
#  Text(0.05084745762711865, 0.4090909090909091, 'X[0] <= 1.027\nsquared_error = 0.082\nsamples = 5\nvalue = 31.64'),
#  Text(0.0423728813559322, 0.3181818181818182, 'X[0] <= 1.027\nsquared_error = 0.002\nsamples = 2\nvalue = 31.95'),
#  Text(0.038135593220338986, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 32.0'),
#  Text(0.046610169491525424, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 31.9'),
#  Text(0.059322033898305086, 0.3181818181818182, 'X[0] <= 1.028\nsquared_error = 0.029\nsamples = 3\nvalue = 31.433'),
#  Text(0.05508474576271186, 0.22727272727272727, 'X[1] <= 108.25\nsquared_error = 0.003\nsamples = 2\nvalue = 31.55'),
#  Text(0.05084745762711865, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 31.5'),
#  Text(0.059322033898305086, 0.13636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 31.6'),
#  Text(0.0635593220338983, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 31.2'),
#  Text(0.08050847457627118, 0.5, 'X[4] <= 226.375\nsquared_error = 0.072\nsamples = 4\nvalue = 34.65'),
#  Text(0.07203389830508475, 0.4090909090909091, 'X[1] <= 115.95\nsquared_error = 0.01\nsamples = 2\nvalue = 34.9'),
#  Text(0.06779661016949153, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 34.8'),
#  Text(0.07627118644067797, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 35.0'),
#  Text(0.08898305084745763, 0.4090909090909091, 'X[3] <= 118.75\nsquared_error = 0.01\nsamples = 2\nvalue = 34.4'),
#  Text(0.0847457627118644, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 34.3'),
#  Text(0.09322033898305085, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 34.5'),
#  Text(0.1419491525423729, 0.5909090909090909, 'X[0] <= 1.033\nsquared_error = 0.686\nsamples = 17\nvalue = 29.218'),
#  Text(0.11864406779661017, 0.5, 'X[0] <= 1.031\nsquared_error = 0.179\nsamples = 9\nvalue = 29.889'),
#  Text(0.1059322033898305, 0.4090909090909091, 'X[2] <= 113.65\nsquared_error = 0.023\nsamples = 2\nvalue = 30.55'),
#  Text(0.1016949152542373, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 30.7'),
#  Text(0.11016949152542373, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 30.4'),
#  Text(0.13135593220338984, 0.4090909090909091, 'X[0] <= 1.032\nsquared_error = 0.063\nsamples = 7\nvalue = 29.7'),
#  Text(0.11864406779661017, 0.3181818181818182, 'X[2] <= 102.95\nsquared_error = 0.005\nsamples = 4\nvalue = 29.9'),
#  Text(0.11440677966101695, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 29.8'),
#  Text(0.1228813559322034, 0.22727272727272727, 'X[4] <= 186.625\nsquared_error = 0.002\nsamples = 3\nvalue = 29.933'),
#  Text(0.11864406779661017, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 30.0'),
#  Text(0.1271186440677966, 0.13636363636363635, 'squared_error = -0.0\nsamples = 2\nvalue = 29.9'),
#  Text(0.1440677966101695, 0.3181818181818182, 'X[4] <= 197.125\nsquared_error = 0.016\nsamples = 3\nvalue = 29.433'),
#  Text(0.13983050847457626, 0.22727272727272727, 'X[0] <= 1.033\nsquared_error = 0.002\nsamples = 2\nvalue = 29.35'),
#  Text(0.13559322033898305, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 29.4'),
#  Text(0.1440677966101695, 0.13636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 29.3'),
#  Text(0.1483050847457627, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 29.6'),
#  Text(0.1652542372881356, 0.5, 'X[0] <= 1.034\nsquared_error = 0.18\nsamples = 8\nvalue = 28.463'),
#  Text(0.15677966101694915, 0.4090909090909091, 'X[0] <= 1.034\nsquared_error = 0.022\nsamples = 4\nvalue = 28.85'),
#  Text(0.15254237288135594, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 29.0'),
#  Text(0.16101694915254236, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 28.7'),
#  Text(0.17372881355932204, 0.4090909090909091, 'X[1] <= 99.0\nsquared_error = 0.037\nsamples = 4\nvalue = 28.075'),
#  Text(0.1694915254237288, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 28.4'),
#  Text(0.17796610169491525, 0.3181818181818182, 'X[4] <= 203.875\nsquared_error = 0.002\nsamples = 3\nvalue = 27.967'),
#  Text(0.17372881355932204, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 28.0'),
#  Text(0.18220338983050846, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 27.9'),
#  Text(0.3765889830508475, 0.7727272727272727, 'X[0] <= 1.047\nsquared_error = 6.227\nsamples = 69\nvalue = 23.142'),
#  Text(0.2807203389830508, 0.6818181818181818, 'X[0] <= 1.041\nsquared_error = 1.557\nsamples = 33\nvalue = 25.427'),
#  Text(0.23834745762711865, 0.5909090909090909, 'X[0] <= 1.039\nsquared_error = 0.262\nsamples = 14\nvalue = 26.657'),
#  Text(0.21822033898305085, 0.5, 'X[0] <= 1.038\nsquared_error = 0.061\nsamples = 10\nvalue = 26.95'),
#  Text(0.2033898305084746, 0.4090909090909091, 'X[0] <= 1.037\nsquared_error = 0.012\nsamples = 6\nvalue = 27.133'),
#  Text(0.19491525423728814, 0.3181818181818182, 'X[0] <= 1.037\nsquared_error = 0.002\nsamples = 3\nvalue = 27.233'),
#  Text(0.1906779661016949, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 27.3'),
#  Text(0.19915254237288135, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 27.2'),
#  Text(0.211864406779661, 0.3181818181818182, 'X[2] <= 103.2\nsquared_error = 0.002\nsamples = 3\nvalue = 27.033'),
#  Text(0.2076271186440678, 0.22727272727272727, 'X[0] <= 1.038\nsquared_error = 0.0\nsamples = 2\nvalue = 27.0'),
#  Text(0.2033898305084746, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 27.0'),
#  Text(0.211864406779661, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 27.0'),
#  Text(0.21610169491525424, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 27.1'),
#  Text(0.2330508474576271, 0.4090909090909091, 'X[0] <= 1.039\nsquared_error = 0.007\nsamples = 4\nvalue = 26.675'),
#  Text(0.2288135593220339, 0.3181818181818182, 'X[0] <= 1.038\nsquared_error = 0.003\nsamples = 2\nvalue = 26.75'),
#  Text(0.2245762711864407, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 26.8'),
#  Text(0.2330508474576271, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 26.7'),
#  Text(0.23728813559322035, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 26.6'),
#  Text(0.2584745762711864, 0.5, 'X[0] <= 1.04\nsquared_error = 0.017\nsamples = 4\nvalue = 25.925'),
#  Text(0.25, 0.4090909090909091, 'X[2] <= 104.35\nsquared_error = 0.002\nsamples = 2\nvalue = 26.05'),
#  Text(0.2457627118644068, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 26.1'),
#  Text(0.2542372881355932, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 26.0'),
#  Text(0.2669491525423729, 0.4090909090909091, 'X[3] <= 96.85\nsquared_error = 0.0\nsamples = 2\nvalue = 25.8'),
#  Text(0.2627118644067797, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 25.8'),
#  Text(0.2711864406779661, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 25.8'),
#  Text(0.3230932203389831, 0.5909090909090909, 'X[0] <= 1.043\nsquared_error = 0.575\nsamples = 19\nvalue = 24.521'),
#  Text(0.298728813559322, 0.5, 'X[0] <= 1.042\nsquared_error = 0.045\nsamples = 9\nvalue = 25.211'),
#  Text(0.288135593220339, 0.4090909090909091, 'X[0] <= 1.041\nsquared_error = 0.01\nsamples = 7\nvalue = 25.314'),
#  Text(0.2796610169491525, 0.3181818181818182, 'X[0] <= 1.041\nsquared_error = 0.002\nsamples = 2\nvalue = 25.45'),
#  Text(0.2754237288135593, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 25.5'),
#  Text(0.2838983050847458, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 25.4'),
#  Text(0.2966101694915254, 0.3181818181818182, 'X[0] <= 1.041\nsquared_error = 0.002\nsamples = 5\nvalue = 25.26'),
#  Text(0.2923728813559322, 0.22727272727272727, 'X[4] <= 169.625\nsquared_error = 0.0\nsamples = 3\nvalue = 25.3'),
#  Text(0.288135593220339, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 25.3'),
#  Text(0.2966101694915254, 0.13636363636363635, 'squared_error = -0.0\nsamples = 2\nvalue = 25.3'),
#  Text(0.3008474576271186, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 25.2'),
#  Text(0.3093220338983051, 0.4090909090909091, 'X[2] <= 105.3\nsquared_error = 0.002\nsamples = 2\nvalue = 24.85'),
#  Text(0.3050847457627119, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.3135593220338983, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 24.9'),
#  Text(0.3474576271186441, 0.5, 'X[0] <= 1.045\nsquared_error = 0.238\nsamples = 10\nvalue = 23.9'),
#  Text(0.3305084745762712, 0.4090909090909091, 'X[0] <= 1.044\nsquared_error = 0.01\nsamples = 5\nvalue = 24.36'),
#  Text(0.3220338983050847, 0.3181818181818182, 'X[0] <= 1.043\nsquared_error = 0.002\nsamples = 3\nvalue = 24.433'),
#  Text(0.3177966101694915, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.326271186440678, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 24.4'),
#  Text(0.3389830508474576, 0.3181818181818182, 'X[3] <= 102.35\nsquared_error = 0.002\nsamples = 2\nvalue = 24.25'),
#  Text(0.3347457627118644, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 24.3'),
#  Text(0.3432203389830508, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 24.2'),
#  Text(0.3644067796610169, 0.4090909090909091, 'X[4] <= 168.875\nsquared_error = 0.042\nsamples = 5\nvalue = 23.44'),
#  Text(0.3559322033898305, 0.3181818181818182, 'X[2] <= 103.5\nsquared_error = 0.01\nsamples = 2\nvalue = 23.2'),
#  Text(0.3516949152542373, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.3601694915254237, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.3728813559322034, 0.3181818181818182, 'X[0] <= 1.045\nsquared_error = 0.0\nsamples = 3\nvalue = 23.6'),
#  Text(0.3686440677966102, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 23.6'),
#  Text(0.3771186440677966, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 23.6'),
#  Text(0.4724576271186441, 0.6818181818181818, 'X[0] <= 1.051\nsquared_error = 1.332\nsamples = 36\nvalue = 21.047'),
#  Text(0.4343220338983051, 0.5909090909090909, 'X[0] <= 1.049\nsquared_error = 0.385\nsamples = 18\nvalue = 22.022'),
#  Text(0.413135593220339, 0.5, 'X[0] <= 1.048\nsquared_error = 0.108\nsamples = 11\nvalue = 22.455'),
#  Text(0.3983050847457627, 0.4090909090909091, 'X[0] <= 1.047\nsquared_error = 0.022\nsamples = 6\nvalue = 22.733'),
#  Text(0.3898305084745763, 0.3181818181818182, 'X[2] <= 94.8\nsquared_error = 0.002\nsamples = 3\nvalue = 22.867'),
#  Text(0.3855932203389831, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 22.8'),
#  Text(0.3940677966101695, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 22.9'),
#  Text(0.4067796610169492, 0.3181818181818182, 'X[3] <= 100.75\nsquared_error = 0.007\nsamples = 3\nvalue = 22.6'),
#  Text(0.4025423728813559, 0.22727272727272727, 'X[0] <= 1.047\nsquared_error = 0.003\nsamples = 2\nvalue = 22.65'),
#  Text(0.3983050847457627, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 22.7'),
#  Text(0.4067796610169492, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.4110169491525424, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 22.5'),
#  Text(0.4279661016949153, 0.4090909090909091, 'X[2] <= 101.65\nsquared_error = 0.006\nsamples = 5\nvalue = 22.12'),
#  Text(0.423728813559322, 0.3181818181818182, 'X[3] <= 96.55\nsquared_error = 0.002\nsamples = 3\nvalue = 22.067'),
#  Text(0.4194915254237288, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.4279661016949153, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 22.1'),
#  Text(0.4322033898305085, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 22.2'),
#  Text(0.4555084745762712, 0.5, 'X[0] <= 1.05\nsquared_error = 0.065\nsamples = 7\nvalue = 21.343'),
#  Text(0.4449152542372881, 0.4090909090909091, 'X[2] <= 97.75\nsquared_error = 0.023\nsamples = 2\nvalue = 21.65'),
#  Text(0.4406779661016949, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 21.5'),
#  Text(0.4491525423728814, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 21.8'),
#  Text(0.4661016949152542, 0.4090909090909091, 'X[1] <= 93.35\nsquared_error = 0.03\nsamples = 5\nvalue = 21.22'),
#  Text(0.4576271186440678, 0.3181818181818182, 'X[3] <= 100.2\nsquared_error = 0.002\nsamples = 2\nvalue = 21.35'),
#  Text(0.4533898305084746, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 21.3'),
#  Text(0.461864406779661, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 21.4'),
#  Text(0.4745762711864407, 0.3181818181818182, 'X[1] <= 94.7\nsquared_error = 0.029\nsamples = 3\nvalue = 21.133'),
#  Text(0.4703389830508475, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(0.4788135593220339, 0.22727272727272727, 'X[4] <= 208.5\nsquared_error = 0.002\nsamples = 2\nvalue = 21.25'),
#  Text(0.4745762711864407, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.4830508474576271, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 21.3'),
#  Text(0.510593220338983, 0.5909090909090909, 'X[0] <= 1.054\nsquared_error = 0.379\nsamples = 18\nvalue = 20.072'),
#  Text(0.4957627118644068, 0.5, 'X[0] <= 1.052\nsquared_error = 0.069\nsamples = 12\nvalue = 20.475'),
#  Text(0.4872881355932203, 0.4090909090909091, 'X[3] <= 104.45\nsquared_error = 0.009\nsamples = 3\nvalue = 20.867'),
#  Text(0.4830508474576271, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 20.8'),
#  Text(0.4915254237288136, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.5042372881355932, 0.4090909090909091, 'X[2] <= 97.9\nsquared_error = 0.02\nsamples = 9\nvalue = 20.344'),
#  Text(0.5, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 20.1'),
#  Text(0.5084745762711864, 0.3181818181818182, 'X[0] <= 1.052\nsquared_error = 0.004\nsamples = 7\nvalue = 20.414'),
#  Text(0.5042372881355932, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 20.5'),
#  Text(0.5127118644067796, 0.22727272727272727, 'X[2] <= 107.8\nsquared_error = 0.002\nsamples = 5\nvalue = 20.38'),
#  Text(0.5084745762711864, 0.13636363636363635, 'squared_error = -0.0\nsamples = 4\nvalue = 20.4'),
#  Text(0.5169491525423728, 0.13636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.5254237288135594, 0.5, 'X[3] <= 112.25\nsquared_error = 0.026\nsamples = 6\nvalue = 19.267'),
#  Text(0.5211864406779662, 0.4090909090909091, 'X[0] <= 1.055\nsquared_error = 0.004\nsamples = 5\nvalue = 19.2'),
#  Text(0.5169491525423728, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.5254237288135594, 0.3181818181818182, 'X[0] <= 1.055\nsquared_error = 0.002\nsamples = 4\nvalue = 19.175'),
#  Text(0.5211864406779662, 0.22727272727272727, 'squared_error = 0.0\nsamples = 3\nvalue = 19.2'),
#  Text(0.5296610169491526, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 19.1'),
#  Text(0.5296610169491526, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.7801906779661016, 0.8636363636363636, 'X[0] <= 1.073\nsquared_error = 20.846\nsamples = 98\nvalue = 11.713'),
#  Text(0.6469809322033898, 0.7727272727272727, 'X[0] <= 1.065\nsquared_error = 6.622\nsamples = 54\nvalue = 15.087'),
#  Text(0.6032838983050848, 0.6818181818181818, 'X[0] <= 1.062\nsquared_error = 1.486\nsamples = 32\nvalue = 16.7'),
#  Text(0.573093220338983, 0.5909090909090909, 'X[0] <= 1.058\nsquared_error = 0.549\nsamples = 21\nvalue = 17.448'),
#  Text(0.5550847457627118, 0.5, 'X[0] <= 1.057\nsquared_error = 0.109\nsamples = 8\nvalue = 18.287'),
#  Text(0.5466101694915254, 0.4090909090909091, 'X[0] <= 1.056\nsquared_error = 0.029\nsamples = 3\nvalue = 18.633'),
#  Text(0.5423728813559322, 0.3181818181818182, 'X[4] <= 183.0\nsquared_error = 0.003\nsamples = 2\nvalue = 18.75'),
#  Text(0.538135593220339, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 18.8'),
#  Text(0.5466101694915254, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 18.7'),
#  Text(0.5508474576271186, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 18.4'),
#  Text(0.5635593220338984, 0.4090909090909091, 'X[0] <= 1.058\nsquared_error = 0.042\nsamples = 5\nvalue = 18.08'),
#  Text(0.559322033898305, 0.3181818181818182, 'X[1] <= 91.65\nsquared_error = 0.007\nsamples = 4\nvalue = 18.175'),
#  Text(0.5550847457627118, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 18.1'),
#  Text(0.5635593220338984, 0.22727272727272727, 'X[1] <= 97.4\nsquared_error = 0.002\nsamples = 2\nvalue = 18.25'),
#  Text(0.559322033898305, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 18.2'),
#  Text(0.5677966101694916, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 18.3'),
#  Text(0.5677966101694916, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 17.7'),
#  Text(0.5911016949152542, 0.5, 'X[0] <= 1.06\nsquared_error = 0.119\nsamples = 13\nvalue = 16.931'),
#  Text(0.5805084745762712, 0.4090909090909091, 'X[0] <= 1.059\nsquared_error = 0.007\nsamples = 4\nvalue = 17.375'),
#  Text(0.576271186440678, 0.3181818181818182, 'X[0] <= 1.059\nsquared_error = 0.002\nsamples = 2\nvalue = 17.45'),
#  Text(0.5720338983050848, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 17.5'),
#  Text(0.5805084745762712, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 17.4'),
#  Text(0.5847457627118644, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 17.3'),
#  Text(0.6016949152542372, 0.4090909090909091, 'X[0] <= 1.061\nsquared_error = 0.042\nsamples = 9\nvalue = 16.733'),
#  Text(0.5932203389830508, 0.3181818181818182, 'X[4] <= 172.0\nsquared_error = 0.002\nsamples = 4\nvalue = 16.95'),
#  Text(0.5889830508474576, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 17.0'),
#  Text(0.597457627118644, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 16.9'),
#  Text(0.6101694915254238, 0.3181818181818182, 'X[0] <= 1.061\nsquared_error = 0.006\nsamples = 5\nvalue = 16.56'),
#  Text(0.6059322033898306, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 16.7'),
#  Text(0.614406779661017, 0.22727272727272727, 'X[1] <= 93.55\nsquared_error = 0.002\nsamples = 4\nvalue = 16.525'),
#  Text(0.6101694915254238, 0.13636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 16.5'),
#  Text(0.6186440677966102, 0.13636363636363635, 'X[4] <= 210.25\nsquared_error = 0.003\nsamples = 2\nvalue = 16.55'),
#  Text(0.614406779661017, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 16.6'),
#  Text(0.6228813559322034, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 16.5'),
#  Text(0.6334745762711864, 0.5909090909090909, 'X[0] <= 1.063\nsquared_error = 0.171\nsamples = 11\nvalue = 15.273'),
#  Text(0.6186440677966102, 0.5, 'X[1] <= 85.25\nsquared_error = 0.042\nsamples = 3\nvalue = 15.867'),
#  Text(0.614406779661017, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 15.6'),
#  Text(0.6228813559322034, 0.4090909090909091, 'X[2] <= 104.15\nsquared_error = 0.01\nsamples = 2\nvalue = 16.0'),
#  Text(0.6186440677966102, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 16.1'),
#  Text(0.6271186440677966, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 15.9'),
#  Text(0.6483050847457628, 0.5, 'X[0] <= 1.065\nsquared_error = 0.037\nsamples = 8\nvalue = 15.05'),
#  Text(0.6398305084745762, 0.4090909090909091, 'X[0] <= 1.064\nsquared_error = 0.012\nsamples = 4\nvalue = 15.225'),
#  Text(0.635593220338983, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 15.4'),
#  Text(0.6440677966101694, 0.3181818181818182, 'X[0] <= 1.064\nsquared_error = 0.002\nsamples = 3\nvalue = 15.167'),
#  Text(0.6398305084745762, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 15.2'),
#  Text(0.6483050847457628, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 15.1'),
#  Text(0.6567796610169492, 0.4090909090909091, 'X[0] <= 1.065\nsquared_error = 0.002\nsamples = 4\nvalue = 14.875'),
#  Text(0.652542372881356, 0.3181818181818182, 'squared_error = 0.0\nsamples = 3\nvalue = 14.9'),
#  Text(0.6610169491525424, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 14.8'),
#  Text(0.690677966101695, 0.6818181818181818, 'X[2] <= 90.0\nsquared_error = 4.804\nsamples = 22\nvalue = 12.741'),
#  Text(0.6716101694915254, 0.5909090909090909, 'X[0] <= 1.068\nsquared_error = 10.58\nsamples = 3\nvalue = 10.2'),
#  Text(0.6673728813559322, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 5.6'),
#  Text(0.6758474576271186, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 12.5'),
#  Text(0.7097457627118644, 0.5909090909090909, 'X[0] <= 1.068\nsquared_error = 2.712\nsamples = 19\nvalue = 13.142'),
#  Text(0.684322033898305, 0.5, 'X[2] <= 91.95\nsquared_error = 2.122\nsamples = 9\nvalue = 14.467'),
#  Text(0.673728813559322, 0.4090909090909091, 'X[0] <= 1.067\nsquared_error = 5.062\nsamples = 2\nvalue = 16.25'),
#  Text(0.6694915254237288, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 18.5'),
#  Text(0.6779661016949152, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 14.0'),
#  Text(0.6949152542372882, 0.4090909090909091, 'X[0] <= 1.067\nsquared_error = 0.114\nsamples = 7\nvalue = 13.957'),
#  Text(0.6864406779661016, 0.3181818181818182, 'X[2] <= 100.25\nsquared_error = 0.047\nsamples = 3\nvalue = 14.3'),
#  Text(0.6822033898305084, 0.22727272727272727, 'X[1] <= 84.2\nsquared_error = 0.003\nsamples = 2\nvalue = 14.15'),
#  Text(0.6779661016949152, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 14.2'),
#  Text(0.6864406779661016, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 14.1'),
#  Text(0.690677966101695, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 14.6'),
#  Text(0.7033898305084746, 0.3181818181818182, 'X[0] <= 1.068\nsquared_error = 0.01\nsamples = 4\nvalue = 13.7'),
#  Text(0.6991525423728814, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 13.8'),
#  Text(0.7076271186440678, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 13.6'),
#  Text(0.7351694915254238, 0.5, 'X[0] <= 1.072\nsquared_error = 0.242\nsamples = 10\nvalue = 11.95'),
#  Text(0.7161016949152542, 0.4090909090909091, 'X[4] <= 152.125\nsquared_error = 0.153\nsamples = 4\nvalue = 12.45'),
#  Text(0.711864406779661, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 13.1'),
#  Text(0.7203389830508474, 0.3181818181818182, 'X[0] <= 1.071\nsquared_error = 0.016\nsamples = 3\nvalue = 12.233'),
#  Text(0.7161016949152542, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 12.4'),
#  Text(0.7245762711864406, 0.22727272727272727, 'X[4] <= 168.75\nsquared_error = 0.003\nsamples = 2\nvalue = 12.15'),
#  Text(0.7203389830508474, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 12.1'),
#  Text(0.7288135593220338, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 12.2'),
#  Text(0.7542372881355932, 0.4090909090909091, 'X[0] <= 1.072\nsquared_error = 0.025\nsamples = 6\nvalue = 11.617'),
#  Text(0.7457627118644068, 0.3181818181818182, 'X[3] <= 99.3\nsquared_error = 0.002\nsamples = 3\nvalue = 11.767'),
#  Text(0.7415254237288136, 0.22727272727272727, 'X[4] <= 155.5\nsquared_error = 0.0\nsamples = 2\nvalue = 11.8'),
#  Text(0.7372881355932204, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.7457627118644068, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.75, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.7'),
#  Text(0.7627118644067796, 0.3181818181818182, 'X[2] <= 92.8\nsquared_error = 0.002\nsamples = 3\nvalue = 11.467'),
#  Text(0.7584745762711864, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.4'),
#  Text(0.7669491525423728, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 11.5'),
#  Text(0.9134004237288136, 0.7727272727272727, 'X[0] <= 1.083\nsquared_error = 7.189\nsamples = 44\nvalue = 7.573'),
#  Text(0.8554025423728814, 0.6818181818181818, 'X[0] <= 1.078\nsquared_error = 1.409\nsamples = 29\nvalue = 9.172'),
#  Text(0.8167372881355932, 0.5909090909090909, 'X[0] <= 1.076\nsquared_error = 0.251\nsamples = 14\nvalue = 10.257'),
#  Text(0.7923728813559322, 0.5, 'X[0] <= 1.074\nsquared_error = 0.058\nsamples = 7\nvalue = 10.686'),
#  Text(0.7838983050847458, 0.4090909090909091, 'X[0] <= 1.074\nsquared_error = 0.007\nsamples = 4\nvalue = 10.875'),
#  Text(0.7796610169491526, 0.3181818181818182, 'X[4] <= 157.0\nsquared_error = 0.003\nsamples = 2\nvalue = 10.95'),
#  Text(0.7754237288135594, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.0'),
#  Text(0.7838983050847458, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.9'),
#  Text(0.788135593220339, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 10.8'),
#  Text(0.8008474576271186, 0.4090909090909091, 'X[4] <= 166.25\nsquared_error = 0.016\nsamples = 3\nvalue = 10.433'),
#  Text(0.7966101694915254, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 10.6'),
#  Text(0.8050847457627118, 0.3181818181818182, 'X[1] <= 85.85\nsquared_error = 0.002\nsamples = 2\nvalue = 10.35'),
#  Text(0.8008474576271186, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.3'),
#  Text(0.809322033898305, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 10.4'),
#  Text(0.8411016949152542, 0.5, 'X[0] <= 1.077\nsquared_error = 0.076\nsamples = 7\nvalue = 9.829'),
#  Text(0.8305084745762712, 0.4090909090909091, 'X[0] <= 1.076\nsquared_error = 0.013\nsamples = 4\nvalue = 10.05'),
#  Text(0.8220338983050848, 0.3181818181818182, 'X[2] <= 89.35\nsquared_error = 0.003\nsamples = 2\nvalue = 10.15'),
#  Text(0.8177966101694916, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.1'),
#  Text(0.826271186440678, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.2'),
#  Text(0.8389830508474576, 0.3181818181818182, 'X[1] <= 85.1\nsquared_error = 0.002\nsamples = 2\nvalue = 9.95'),
#  Text(0.8347457627118644, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 9.9'),
#  Text(0.8432203389830508, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.0'),
#  Text(0.8516949152542372, 0.4090909090909091, 'X[1] <= 80.75\nsquared_error = 0.009\nsamples = 3\nvalue = 9.533'),
#  Text(0.847457627118644, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 9.4'),
#  Text(0.8559322033898306, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 9.6'),
#  Text(0.8940677966101694, 0.5909090909090909, 'X[0] <= 1.08\nsquared_error = 0.366\nsamples = 15\nvalue = 8.16'),
#  Text(0.8771186440677966, 0.5, 'X[0] <= 1.079\nsquared_error = 0.045\nsamples = 8\nvalue = 8.662'),
#  Text(0.8686440677966102, 0.4090909090909091, 'X[1] <= 86.15\nsquared_error = 0.007\nsamples = 4\nvalue = 8.85'),
#  Text(0.864406779661017, 0.3181818181818182, 'squared_error = -0.0\nsamples = 3\nvalue = 8.8'),
#  Text(0.8728813559322034, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 9.0'),
#  Text(0.885593220338983, 0.4090909090909091, 'X[0] <= 1.08\nsquared_error = 0.012\nsamples = 4\nvalue = 8.475'),
#  Text(0.8813559322033898, 0.3181818181818182, 'X[4] <= 166.375\nsquared_error = 0.002\nsamples = 3\nvalue = 8.533'),
#  Text(0.8771186440677966, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 8.5'),
#  Text(0.885593220338983, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 8.6'),
#  Text(0.8898305084745762, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 8.3'),
#  Text(0.9110169491525424, 0.5, 'X[0] <= 1.082\nsquared_error = 0.116\nsamples = 7\nvalue = 7.586'),
#  Text(0.9067796610169492, 0.4090909090909091, 'X[0] <= 1.081\nsquared_error = 0.03\nsamples = 5\nvalue = 7.78'),
#  Text(0.8983050847457628, 0.3181818181818182, 'X[0] <= 1.081\nsquared_error = 0.007\nsamples = 3\nvalue = 7.9'),
#  Text(0.8940677966101694, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.902542372881356, 0.22727272727272727, 'X[4] <= 173.75\nsquared_error = 0.003\nsamples = 2\nvalue = 7.85'),
#  Text(0.8983050847457628, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 7.9'),
#  Text(0.9067796610169492, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 7.8'),
#  Text(0.9152542372881356, 0.3181818181818182, 'X[1] <= 78.75\nsquared_error = 0.01\nsamples = 2\nvalue = 7.6'),
#  Text(0.9110169491525424, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 7.7'),
#  Text(0.9194915254237288, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 7.5'),
#  Text(0.9152542372881356, 0.4090909090909091, 'squared_error = -0.0\nsamples = 2\nvalue = 7.1'),
#  Text(0.9713983050847458, 0.6818181818181818, 'X[0] <= 1.092\nsquared_error = 3.852\nsamples = 15\nvalue = 4.48'),
#  Text(0.9555084745762712, 0.5909090909090909, 'X[0] <= 1.089\nsquared_error = 1.111\nsamples = 12\nvalue = 5.292'),
#  Text(0.9364406779661016, 0.5, 'X[0] <= 1.086\nsquared_error = 0.254\nsamples = 8\nvalue = 5.975'),
#  Text(0.9279661016949152, 0.4090909090909091, 'X[1] <= 78.2\nsquared_error = 0.062\nsamples = 5\nvalue = 6.32'),
#  Text(0.923728813559322, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 6.6'),
#  Text(0.9322033898305084, 0.3181818181818182, 'X[3] <= 97.4\nsquared_error = 0.016\nsamples = 3\nvalue = 6.133'),
#  Text(0.9279661016949152, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 6.3'),
#  Text(0.9364406779661016, 0.22727272727272727, 'X[4] <= 178.625\nsquared_error = 0.003\nsamples = 2\nvalue = 6.05'),
#  Text(0.9322033898305084, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 6.1'),
#  Text(0.940677966101695, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.9449152542372882, 0.4090909090909091, 'X[0] <= 1.087\nsquared_error = 0.047\nsamples = 3\nvalue = 5.4'),
#  Text(0.940677966101695, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 5.7'),
#  Text(0.9491525423728814, 0.3181818181818182, 'X[2] <= 92.5\nsquared_error = 0.003\nsamples = 2\nvalue = 5.25'),
#  Text(0.9449152542372882, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 5.3'),
#  Text(0.9533898305084746, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 5.2'),
#  Text(0.9745762711864406, 0.5, 'X[0] <= 1.091\nsquared_error = 0.022\nsamples = 4\nvalue = 3.925'),
#  Text(0.9703389830508474, 0.4090909090909091, 'X[1] <= 80.05\nsquared_error = 0.007\nsamples = 3\nvalue = 4.0'),
#  Text(0.9661016949152542, 0.3181818181818182, 'X[3] <= 87.9\nsquared_error = 0.002\nsamples = 2\nvalue = 3.95'),
#  Text(0.961864406779661, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.9703389830508474, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 3.9'),
#  Text(0.9745762711864406, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 4.1'),
#  Text(0.9788135593220338, 0.4090909090909091, 'squared_error = -0.0\nsamples = 1\nvalue = 3.7'),
#  Text(0.9872881355932204, 0.5909090909090909, 'X[0] <= 1.095\nsquared_error = 1.642\nsamples = 3\nvalue = 1.233'),
#  Text(0.9830508474576272, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.9915254237288136, 0.5, 'X[0] <= 1.104\nsquared_error = 0.123\nsamples = 2\nvalue = 0.35'),
#  Text(0.9872881355932204, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 0.7'),
#  Text(0.9957627118644068, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0')]

# %%
path=reg.cost_complexity_pruning_path(x_train,y_train)
ccp_alpha=path.ccp_alphas

# %%
alphalist=[]
for i in range(len(ccp_alpha)):
    reg=DecisionTreeRegressor(ccp_alpha=ccp_alpha[i])
    reg.fit(x_train,y_train)
    alphalist.append(reg)

# %%
trainscore=[alphalist[i].score(x_train,y_train) for i in range(len(alphalist))]
testscore=[alphalist[i].score(x_test,y_test) for i in range(len(alphalist))]
plt.xlabel('alpha')
plt.ylabel('accuracy')
plt.plot(ccp_alpha,trainscore,marker='o',label='training',color='magenta',drawstyle='steps-post')
plt.plot(ccp_alpha,testscore,marker='+',label='testing',color='red',drawstyle='steps-post')
plt.legend()
plt.show()

# %%
clf=DecisionTreeRegressor(ccp_alpha=1)
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
print(f'Decision Tree Normal Approach :{metrics.r2_score(y_test,y_pred)}')

rf=RandomForestRegressor(n_estimators=1000,ccp_alpha=1)
rf.fit(x_train,y_train)
y_pred_rf=rf.predict(x_test)
print(f'Random Forest Normal Approach : {metrics.r2_score(y_test,y_pred_rf)}')
# Out:
# Decision Tree Normal Approach :0.9033832426523649
# Random Forest Normal Approach : 0.9305582309490047

# %%
params={
    'RandomForest':{
        'model':RandomForestRegressor(),
        'params':{
            'n_estimators':[int(x) for x in np.linspace(start=1,stop=1200,num=10)],
            'criterion':['mse','mae'],
            'max_depth':[int(x) for x in np.linspace(start=1,stop=30,num=5)],
            'min_samples_split':[2,5,10,12],
            'min_samples_leaf':[2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[1,2,2,5,3,3,5,4,5],
        }
    },
    
    'D-tree':{
        'model':RandomForestRegressor(),
        'params':{
            'criterion':['mse','mae'],
           # 'splitter':['best','random'],
            'min_samples_split':[1,2,5,10,12],
            'min_samples_leaf':[1,2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[1,2,2,5,3,3,5,4,5],
        }
    },
    'SVM':{
        'model':SVR(),
        'params':{
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,0.025,0.50,0.75],
            'kernel':['linear','poly','rbf','sigmoid'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)]
        }
    }
}

# %%
scores=[]
for modelname,mp in params.items():
    clf=RandomizedSearchCV(mp['model'],param_distributions=mp['params'],
                          cv=5,n_jobs=-1,n_iter=10,scoring='neg_mean_squared_error')
    
    clf.fit(x_train,y_train)
    scores.append({
        'model_name':modelname,
        'best_score':clf.best_score_,
        'best_estimator':clf.best_estimator_
    })
# Out:
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:403: FutureWarning: Criterion 'mae' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='absolute_error'` which is equivalent.
#   warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\abhin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\abhin\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 450, in fit
#     trees = Parallel(
#   File "C:\Users\abhin\anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\abhin\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\abhin\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\abhin\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\abhin\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\abhin\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\abhin\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\abhin\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\abhin\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 185, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\abhin\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1315, in fit
#     super().fit(
#   File "C:\Users\abhin\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 250, in fit
#     raise ValueError(
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [         nan  -9.43172919 -45.8016367  -27.41176485  -6.01623763
#   -5.52966231 -73.3885909  -10.78574926  -5.8355085           nan]
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=84).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %%
scoresdf=pd.DataFrame(scores,columns=['model_name','best_score','best_estimator'])
scoresdf
# Out:
#      model_name  best_score                                     best_estimator
# 0  RandomForest  -14.483985  (DecisionTreeRegressor(ccp_alpha=1, criterion=...
# 1        D-tree   -5.529662  (DecisionTreeRegressor(ccp_alpha=2, max_featur...
# 2           SVM  -43.054809  SVR(C=0.75, kernel='poly', max_iter=84, tol=0.75)

# %%
scores[0]['best_estimator']
# Out:
# RandomForestRegressor(ccp_alpha=1, criterion='mae', max_depth=30,
#                       min_samples_leaf=2, min_samples_split=10,
#                       n_estimators=1200)

# %%
rf=scores[0]['best_estimator']
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
print(metrics.r2_score(y_test,y_pred))
# Out:
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:403: FutureWarning: Criterion 'mae' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='absolute_error'` which is equivalent.
#   warn(
# 0.8129434491216231

# %%
totrainlist=np.array(totrain)
predicted=[]
for i in range(len(totrainlist)):
    predicted.append(rf.predict([totrainlist[i]]))
    
totrain['Actual Result']=test
totrain['predicted Result']=np.array(predicted)
totrain
# Out:
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\abhin\AppData\Local\Temp\ipykernel_23780\3198631488.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totrain['Actual Result']=test
# C:\Users\abhin\AppData\Local\Temp\ipykernel_23780\3198631488.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totrain['predicted Result']=np.array(predicted)
#      Density  Abdomen  Chest    Hip  Weight  Actual Result  predicted Result
# 0     1.0708     85.2   93.1   94.5  154.25           12.3         11.143625
# 1     1.0853     83.0   93.6   98.7  173.25            6.1         10.822708
# 2     1.0414     87.9   95.8   99.2  154.00           25.3         25.333500
# 3     1.0751     86.4  101.8  101.2  184.75           10.4         10.829875
# 4     1.0340    100.0   97.3  101.9  184.25           28.7         26.936500
# ..       ...      ...    ...    ...     ...            ...               ...
# 247   1.0736     83.6   89.2   88.8  134.25           11.0         10.850708
# 248   1.0236    105.0  108.5  104.5  201.00           33.6         26.936500
# 249   1.0328    111.5  111.1  101.7  186.75           29.3         26.936500
# 250   1.0399    101.3  108.3   97.8  190.75           26.0         26.126417
# 251   1.0271    108.5  112.4  107.1  207.50           31.9         26.936500
#
# [252 rows x 7 columns]

# %%
sn.distplot(totrain['Actual Result'],label='Actual Result',hist=False,color='magenta')
sn.distplot(totrain['predicted Result'],label='predicted Result',hist=False,color='red')
plt.legend()
plt.plot()
# Out:
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abhin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# []

# %%
import pickle
file=open('bodyfatmodel1.pkl','wb')
pickle.dump(rf,file)
file.close()
